# %%
# dlib con be downloaded from here below and you must be aware of path in my case it is "C:\Users\Ce la vie\Desktop\pro\dlib-19.22.99-cp37-cp37m-win_amd64.whl"

#%%cmd
#pip install "C:\Users\Ce la vie\Desktop\pro\dlib-19.22.99-cp37-cp37m-win_amd64.whl"
# Out:
# Microsoft Windows [Version 10.0.10240]
# (c) ��௮��� �������� (Microsoft Corporation), 2015 �. �� �ࠢ� ���饭�.
#
# C:\Users\Ce la vie\Desktop>pip install "C:\Users\Ce la vie\Desktop\pro\dlib-19.22.99-cp37-cp37m-win_amd64.whl"
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\django-5.0.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\pip-24.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: dlib-19.22.99-cp37-cp37m-win_amd64.whl is not a supported wheel on this platform.
# C:\Users\Ce la vie\Desktop>

# %%
#!pip install face-recognition
# Out:
# ...
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      --------------------------------------- 0.0/100.1 MB 72.6 kB/s eta 0:22:59
#      -------------------------------------- 0.0/100.1 MB 131.3 kB/s eta 0:12:43
#      -------------------------------------- 0.1/100.1 MB 217.9 kB/s eta 0:07:40
#      -------------------------------------- 0.1/100.1 MB 286.7 kB/s eta 0:05:50
#      -------------------------------------- 0.1/100.1 MB 275.8 kB/s eta 0:06:03
#      -------------------------------------- 0.1/100.1 MB 275.8 kB/s eta 0:06:03
#      -------------------------------------- 0.1/100.1 MB 327.9 kB/s eta 0:05:06
# ...

# %%
#%%cmd
#pip install cmake
# Out:
# Microsoft Windows [Version 10.0.10240]
# (c) ��௮��� �������� (Microsoft Corporation), 2015 �. �� �ࠢ� ���饭�.
#
# C:\Users\Ce la vie\Desktop>pip install cmake
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\django-5.0.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\pip-24.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
#%%cmd
#pip install "C:\Users\Ce la vie\Desktop\pro\drive-download-20240609T165119Z-001\dlib-19.24.1-cp311-cp311-win_amd64.whl"
# Out:
# Microsoft Windows [Version 10.0.10240]
# (c) ��௮��� �������� (Microsoft Corporation), 2015 �. �� �ࠢ� ���饭�.
#
# C:\Users\Ce la vie\Desktop>pip install "C:\Users\Ce la vie\Desktop\pro\drive-download-20240609T165119Z-001\dlib-19.24.1-cp311-cp311-win_amd64.whl"
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\django-5.0.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\pip-24.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Processing c:\users\ce la vie\desktop\pro\drive-download-20240609t165119z-001\dlib-19.24.1-cp311-cp311-win_amd64.whl
# ...
#
# C:\Users\Ce la vie\Desktop>

# %%
#!pip install face-recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\django-5.0.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\ce la vie\anaconda3\lib\site-packages\pip-24.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import face_recognition 
import cv2
import numpy as np
import csv 
import os 
from datetime import datetime 

video_capture=cv2.VideoCapture(0)


jobs_image=face_recognition.load_image_file(r"C:\Users\Ce la vie\Desktop\pro\Untitled Folder\photos\jobs.jpg")
jobs_encoding=face_recognition.face_encodings(jobs_image)[0]

Ahmetshad_image=face_recognition.load_image_file(r"C:\Users\Ce la vie\Desktop\pro\Untitled Folder\photos\Ahmet shad.jpg")
Ahmetshad_encoding=face_recognition.face_encodings(Ahmetshad_image)[0]

Putin_image=face_recognition.load_image_file(r"C:\Users\Ce la vie\Desktop\pro\Untitled Folder\photos\Putin.jpg")
Putin_encoding=face_recognition.face_encodings(Putin_image)[0]


ZyleyhaKakayew_image=face_recognition.load_image_file(r"C:\Users\Ce la vie\Desktop\pro\Untitled Folder\photos\Zyleyha.jpg")
Zyleyha_encoding=face_recognition.face_encodings(ZyleyhaKakayew_image)[0]

known_face_encoding=[
    jobs_encoding,
    Ahmetshad_encoding,
    Putin_encoding,
    Zyleyha_encoding
]


known_faces_names=[
    "jobs",
    "Ahmet shad",
    "Putin",
    "Zyleyha"
]

students=known_faces_names.copy()

face_locations=[]
face_encodings=[]
face_names=[]
s=True 
now=datetime.now()
current_date=now.strftime("%Y-%m-%d")

f=open(current_date+'.csv','w+',newline='')
lnwriter=csv.writer(f)


while True:
    _,frame=video_capture.read(0)
    small_frame=cv2.resize(frame,(0,0),fx=0.25,fy=0.25)
    rgb_small_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)
    if s:
        face_locations=face_recognition.face_locations(rgb_small_frame)
        face_encodings=face_recognition.face_encodings(rgb_small_frame,face_locations)
        face_names=[]
        for face_encoding in face_encodings:
            matches=face_recognition.compare_faces(known_face_encoding,face_encoding)
            name=""
            face_distance=face_recognition.face_distance(known_face_encoding,face_encoding)
            best_matches_index=np.argmin(face_distance)
            if matches[best_matches_index]:
                name=known_faces_names[best_matches_index]
            face_names.append(name)
            
            
            if name in known_faces_names:
                if name in students:
                    students.remove(name)
                    print(students)
                    current_time=now.strftime("%H-%M-%S")
                    lnwriter.writerow([name,current_time])
    cv2.imshow('attendence system',frame)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break 
video_capture.release()
cv2.destroyAllWindows()
f.close()
# Out:
# ['jobs', 'Ahmet shad', 'Putin']
# ['jobs', 'Putin']

# %%
video_capture.release()
cv2.destroyAllWindows()
